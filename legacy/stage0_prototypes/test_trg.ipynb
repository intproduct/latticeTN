# %%
import torch as tc
import torch.nn as nn
import matplotlib.pyplot as plt
import math as mt

class InfTRG(nn.Module):
    """无穷大张量网络的TRG收缩"""
    def __init__(self, tensor, boundary='open', dtype=tc.complex128, device=tc.device('cpu')):
        super().__init__()
        self.tensors = tensor  # 不等价张量
        self.boundary = boundary
        self.dtype = dtype
        self.device = device

    def RG_for_tensor(self):
